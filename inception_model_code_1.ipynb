# %%
# %env SM_FRAMEWORK=tf.keras

# %%
 # %pip install numpy==1.21
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy==1.21 in /usr/local/lib/python3.9/dist-packages (1.21.0)

# %%
 # %pip install tensorflow --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (2.11.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.21.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.25.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (6.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.10)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)

# %%
 # %pip install keras --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.9/dist-packages (2.11.0)

# %%
 # %pip install -U segmentation-models --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting image-classifiers==1.0.0
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 6.6 MB/s eta 0:00:00
# Collecting efficientnet==1.0.0
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.9/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.21.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.1.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.9.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.2.28)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.0)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
 # %pip install -U -q segmentation-models

 import os
 os.environ["SM_FRAMEWORK"] = "tf.keras"

# %%
import os
import cv2
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
from matplotlib import pyplot as plt
import segmentation_models as sm
from tensorflow.python.keras.metrics import MeanIoU

import random
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!unzip /content/drive/MyDrive/data_for_keras_aug_200.zip -d /content/drive/MyDrive/data_for_keras_aug_200/
# Out:
# Archive:  /content/drive/MyDrive/data_for_keras_aug_200.zip

# %%
################################################################
#Get an understanding by looking at a few random images and masks 

train_img_dir = "/content/drive/MyDrive/data_for_keras_aug_200/data_for_keras_aug/train_images/train/"
train_mask_dir = "/content/drive/MyDrive/data_for_keras_aug_200/data_for_keras_aug/train_masks/train/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))


img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot =cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))
plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')
plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray')
plt.title('Mask')
plt.show()

# %%
# img_list

# %%
################################################################

# Define Generator for images and masks so we can read them directly from the drive. 

seed=24
batch_size=8
n_classes=2

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
from keras.utils import to_categorical

#Use this to preprocess input for transfer learning
BACKBONE = 'inceptionv3'
preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
# #Define a function to perform additional preprocessing after datagen.
# #For example, scale images, convert masks to categorical, etc. 
# def preprocess_data(img, mask, num_class):
#     #Scale images
#     img = scaler.fit_transform(img.reshape(-1, img.shape[-1])).reshape(img.shape)
#     img = preprocess_input(img)  #Preprocess based on the pretrained backbone...
#     #Convert mask to one-hot
#     mask = to_categorical(mask, num_class)
      
#     return (img,mask)

# %%
def preprocess_data(img, mask, num_class):
    # Normalize images
    img = img / 255.0
    # Clip mask values to range [0, num_class-1]
    mask = np.clip(mask, 0, num_class-1)
    # Convert mask to one-hot
    mask = to_categorical(mask, num_class)
    return (img, mask)

# %%
#Define the generator.
#We are not doing any rotation or zoom to make sure mask values are not interpolated.
#It is important to keep pixel values in mask as 0, 1, 2, 3, .....
from keras.preprocessing.image import ImageDataGenerator

# %%
def trainGenerator(train_img_path, train_mask_path, num_class):
    
    img_data_gen_args = dict(horizontal_flip=True,
                      vertical_flip=True,
                      fill_mode='reflect')
    
    image_datagen = ImageDataGenerator(**img_data_gen_args)
    mask_datagen = ImageDataGenerator(**img_data_gen_args)
    
    image_generator = image_datagen.flow_from_directory(
        train_img_path,
        class_mode = None,
        batch_size = batch_size,
        seed = seed)
    
    mask_generator = mask_datagen.flow_from_directory(
        train_mask_path,
        class_mode = None,
        color_mode = 'grayscale',
        batch_size = batch_size,
        seed = seed)
    
    train_generator = zip(image_generator, mask_generator)
    
    for (img, mask) in train_generator:
        img, mask = preprocess_data(img, mask, num_class)
        yield (img, mask)

# %%
train_img_path = "/content/drive/MyDrive/data_for_keras_aug_200/data_for_keras_aug/train_images/"
train_mask_path = "/content/drive/MyDrive/data_for_keras_aug_200/data_for_keras_aug/train_masks/"
train_img_gen = trainGenerator(train_img_path, train_mask_path, num_class=2)

val_img_path = "/content/drive/MyDrive/data_for_keras_aug_200/data_for_keras_aug/val_images/"
val_mask_path = "/content/drive/MyDrive/data_for_keras_aug_200/data_for_keras_aug/val_masks/"
val_img_gen = trainGenerator(val_img_path, val_mask_path, num_class=2)

#Make sure the generator is working and that images and masks are indeed lined up. 
#Verify generator.... In python 3 next() is renamed as __next__()
x, y = train_img_gen.__next__()
# Out:
# Found 246 images belonging to 1 classes.
# Found 246 images belonging to 1 classes.

# %%
for i in range(0,3):
    image = x[i]
    mask = np.argmax(y[i], axis=2)
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.show()

x_val, y_val = val_img_gen.__next__()

for i in range(0,3):
    image = x_val[i]
    mask = np.argmax(y_val[i], axis=2)
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(mask, cmap='gray')
    plt.show()
# Out:
# Found 83 images belonging to 1 classes.
# Found 83 images belonging to 1 classes.

# %%
###########################################################################
#Define the model metrcis and load model. 

num_train_imgs = len(os.listdir('/content/drive/MyDrive/data_for_keras_aug_200/data_for_keras_aug/train_images/train/'))
num_val_images = len(os.listdir('/content/drive/MyDrive/data_for_keras_aug_200/data_for_keras_aug/val_images/val/'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_images//batch_size


IMG_HEIGHT = x.shape[1]
IMG_WIDTH  = x.shape[2]
IMG_CHANNELS = x.shape[3]

n_classes=2

# %%
# !pip install torch torchvision torchaudio -f https://download.pytorch.org/whl/cu111/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/cu111/torch_stable.html
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (0.14.1+cu116)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.9/dist-packages (0.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision) (1.21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision) (2.10)

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# define the checkpoint
checkpoint_path = '/content/drive/MyDrive/checkpoints_vgg19/checkpoint-{epoch:03d}.hdf5'
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
#############################################################################
#Use transfer learning using pretrained encoder in the U-Net
#(make sure you uncomment the preprocess_input part in the
# preprocess_data function above)
################################################################
#Define the model
# define model
model = sm.Linknet(BACKBONE, encoder_weights='imagenet', 
                input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS),
                classes=n_classes, activation='softmax')
model.compile('Adam', loss=sm.losses.categorical_focal_jaccard_loss, metrics=[sm.metrics.iou_score])

#Other losses to try: categorical_focal_dice_loss, cce_jaccard_loss, cce_dice_loss, categorical_focal_loss

#model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=metrics)
print(model.summary())
print(model.input_shape)
#Fit the model
#history = model.fit(my_generator, validation_data=validation_datagen, steps_per_epoch=len(X_train) // 16, validation_steps=len(X_train) // 16, epochs=100)
#Train the model. 
history=model.fit(train_img_gen,
          steps_per_epoch=steps_per_epoch,
          epochs=25,
          verbose=1,
          validation_data=val_img_gen,
          validation_steps=val_steps_per_epoch,
          callbacks=[checkpoint])

model.save('landcover_100_epochs_RESNET_backbone_batch16.hdf5')

##################################################################
#plot the training and validation IoU and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['iou_score']
val_acc = history.history['val_iou_score']

plt.plot(epochs, acc, 'y', label='Training IoU')
plt.plot(epochs, val_acc, 'r', label='Validation IoU')
plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#####################################################
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 32, 32, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 32, 32, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 32, 32, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 32, 32, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 32, 32, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 32, 32, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 32, 32, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 32, 32, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 32, 32, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 32, 32, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 16, 16, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 16, 16, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 16, 16, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 16, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 16, 16, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 16, 16, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 16, 16, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 16, 16, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 16, 16, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 16, 16, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 16, 16, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 16, 16, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 16, 16, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 16, 16, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 16, 16, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 16, 16, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 16, 16, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 16, 16, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 16, 16, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 16, 16, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 16, 16, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 16, 16, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 16, 16, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 16, 16, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 16, 16, 192)  0           ['batch_normalization_58[0][0]']
# ...
#
#  decoder_stage2b_relu (Activati  (None, 64, 64, 72)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage2c_conv (Conv2D)  (None, 64, 64, 192)  13824       ['decoder_stage2b_relu[0][0]']
#
#  decoder_stage2c_bn (BatchNorma  (None, 64, 64, 192)  768        ['decoder_stage2c_conv[0][0]']
#  lization)
#
#  decoder_stage2c_relu (Activati  (None, 64, 64, 192)  0          ['decoder_stage2c_bn[0][0]']
#  on)
#
#  decoder_stage2_add (Add)       (None, 64, 64, 192)  0           ['decoder_stage2c_relu[0][0]',
#                                                                   'activation_4[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 64, 64, 48)   9216        ['decoder_stage2_add[0][0]']
#
#  decoder_stage3a_bn (BatchNorma  (None, 64, 64, 48)  192         ['decoder_stage3a_conv[0][0]']
#  lization)
#
#  decoder_stage3a_relu (Activati  (None, 64, 64, 48)  0           ['decoder_stage3a_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 128, 128, 48  0          ['decoder_stage3a_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage3b_conv (Conv2D)  (None, 128, 128, 48  20736       ['decoder_stage3_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage3b_bn (BatchNorma  (None, 128, 128, 48  192        ['decoder_stage3b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3b_relu (Activati  (None, 128, 128, 48  0          ['decoder_stage3b_bn[0][0]']
#  on)                            )
#
#  decoder_stage3c_conv (Conv2D)  (None, 128, 128, 64  3072        ['decoder_stage3b_relu[0][0]']
#                                 )
#
#  decoder_stage3c_bn (BatchNorma  (None, 128, 128, 64  256        ['decoder_stage3c_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3c_relu (Activati  (None, 128, 128, 64  0          ['decoder_stage3c_bn[0][0]']
#  on)                            )
#
#  decoder_stage3_add (Add)       (None, 128, 128, 64  0           ['decoder_stage3c_relu[0][0]',
#                                 )                                 'activation_2[0][0]']
#
#  decoder_stage4a_conv (Conv2D)  (None, 128, 128, 16  1024        ['decoder_stage3_add[0][0]']
#                                 )
#
#  decoder_stage4a_bn (BatchNorma  (None, 128, 128, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 128, 128, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4_upsampling (UpS  (None, 256, 256, 16  0          ['decoder_stage4a_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4b_conv (Conv2D)  (None, 256, 256, 16  2304        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4b_bn (BatchNorma  (None, 256, 256, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 256, 256, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  decoder_stage4c_conv (Conv2D)  (None, 256, 256, 16  256         ['decoder_stage4b_relu[0][0]']
#                                 )
#
#  decoder_stage4c_bn (BatchNorma  (None, 256, 256, 16  64         ['decoder_stage4c_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4c_relu (Activati  (None, 256, 256, 16  0          ['decoder_stage4c_bn[0][0]']
#  on)                            )
#
#  conv2d_94 (Conv2D)             (None, 256, 256, 2)  290         ['decoder_stage4c_relu[0][0]']
#
#  softmax (Activation)           (None, 256, 256, 2)  0           ['conv2d_94[0][0]']
#
# ==================================================================================================
# Total params: 26,268,546
# Trainable params: 26,228,098
# Non-trainable params: 40,448
# __________________________________________________________________________________________________
# None
# (None, 256, 256, 3)
# Epoch 1/25
# 30/30 [==============================] - ETA: 0s - loss: 0.5407 - iou_score: 0.4740
# Epoch 1: val_loss improved from inf to 0.80612, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-001.hdf5
# 30/30 [==============================] - 143s 3s/step - loss: 0.5407 - iou_score: 0.4740 - val_loss: 0.8061 - val_iou_score: 0.4404
# Epoch 2/25
# 30/30 [==============================] - ETA: 0s - loss: 0.3271 - iou_score: 0.6895
# Epoch 2: val_loss improved from 0.80612 to 0.73643, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-002.hdf5
# 30/30 [==============================] - 12s 409ms/step - loss: 0.3271 - iou_score: 0.6895 - val_loss: 0.7364 - val_iou_score: 0.4569
# Epoch 3/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2721 - iou_score: 0.7511
# Epoch 3: val_loss did not improve from 0.73643
# 30/30 [==============================] - 7s 233ms/step - loss: 0.2721 - iou_score: 0.7511 - val_loss: 1.9957 - val_iou_score: 0.2227
# Epoch 4/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2386 - iou_score: 0.7837
# Epoch 4: val_loss did not improve from 0.73643
# 30/30 [==============================] - 7s 247ms/step - loss: 0.2386 - iou_score: 0.7837 - val_loss: 0.8024 - val_iou_score: 0.4396
# Epoch 5/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2389 - iou_score: 0.7833
# Epoch 5: val_loss improved from 0.73643 to 0.68120, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-005.hdf5
# 30/30 [==============================] - 9s 308ms/step - loss: 0.2389 - iou_score: 0.7833 - val_loss: 0.6812 - val_iou_score: 0.4770
# Epoch 6/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2492 - iou_score: 0.7761
# Epoch 6: val_loss did not improve from 0.68120
# 30/30 [==============================] - 7s 223ms/step - loss: 0.2492 - iou_score: 0.7761 - val_loss: 0.8140 - val_iou_score: 0.4360
# Epoch 7/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2154 - iou_score: 0.8043
# Epoch 7: val_loss did not improve from 0.68120
# 30/30 [==============================] - 7s 249ms/step - loss: 0.2154 - iou_score: 0.8043 - val_loss: 1.1862 - val_iou_score: 0.3431
# Epoch 8/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2125 - iou_score: 0.8080
# Epoch 8: val_loss improved from 0.68120 to 0.40187, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-008.hdf5
# 30/30 [==============================] - 9s 294ms/step - loss: 0.2125 - iou_score: 0.8080 - val_loss: 0.4019 - val_iou_score: 0.6901
# Epoch 9/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2045 - iou_score: 0.8159
# Epoch 9: val_loss did not improve from 0.40187
# 30/30 [==============================] - 7s 239ms/step - loss: 0.2045 - iou_score: 0.8159 - val_loss: 0.4470 - val_iou_score: 0.6291
# Epoch 10/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2088 - iou_score: 0.8115
# Epoch 10: val_loss improved from 0.40187 to 0.28671, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-010.hdf5
# 30/30 [==============================] - 12s 409ms/step - loss: 0.2088 - iou_score: 0.8115 - val_loss: 0.2867 - val_iou_score: 0.7556
# Epoch 11/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1921 - iou_score: 0.8265
# Epoch 11: val_loss did not improve from 0.28671
# 30/30 [==============================] - 6s 202ms/step - loss: 0.1921 - iou_score: 0.8265 - val_loss: 0.3963 - val_iou_score: 0.6738
# Epoch 12/25
# 30/30 [==============================] - ETA: 0s - loss: 0.2079 - iou_score: 0.8132
# Epoch 12: val_loss did not improve from 0.28671
# 30/30 [==============================] - 8s 275ms/step - loss: 0.2079 - iou_score: 0.8132 - val_loss: 0.3172 - val_iou_score: 0.7391
# Epoch 13/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1977 - iou_score: 0.8211
# Epoch 13: val_loss did not improve from 0.28671
# 30/30 [==============================] - 6s 212ms/step - loss: 0.1977 - iou_score: 0.8211 - val_loss: 0.6600 - val_iou_score: 0.5144
# Epoch 14/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1873 - iou_score: 0.8305
# Epoch 14: val_loss did not improve from 0.28671
# 30/30 [==============================] - 6s 208ms/step - loss: 0.1873 - iou_score: 0.8305 - val_loss: 0.6527 - val_iou_score: 0.5612
# Epoch 15/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1995 - iou_score: 0.8211
# Epoch 15: val_loss improved from 0.28671 to 0.28662, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-015.hdf5
# 30/30 [==============================] - 15s 499ms/step - loss: 0.1995 - iou_score: 0.8211 - val_loss: 0.2866 - val_iou_score: 0.7467
# Epoch 16/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1810 - iou_score: 0.8366
# Epoch 16: val_loss did not improve from 0.28662
# 30/30 [==============================] - 7s 216ms/step - loss: 0.1810 - iou_score: 0.8366 - val_loss: 1.3038 - val_iou_score: 0.3480
# Epoch 17/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1793 - iou_score: 0.8385
# Epoch 17: val_loss improved from 0.28662 to 0.26444, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-017.hdf5
# 30/30 [==============================] - 9s 291ms/step - loss: 0.1793 - iou_score: 0.8385 - val_loss: 0.2644 - val_iou_score: 0.7759
# Epoch 18/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1728 - iou_score: 0.8437
# Epoch 18: val_loss did not improve from 0.26444
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1728 - iou_score: 0.8437 - val_loss: 0.3228 - val_iou_score: 0.7381
# Epoch 19/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1950 - iou_score: 0.8246
# Epoch 19: val_loss did not improve from 0.26444
# 30/30 [==============================] - 7s 226ms/step - loss: 0.1950 - iou_score: 0.8246 - val_loss: 0.3817 - val_iou_score: 0.6823
# Epoch 20/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1863 - iou_score: 0.8323
# Epoch 20: val_loss did not improve from 0.26444
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1863 - iou_score: 0.8323 - val_loss: 0.3058 - val_iou_score: 0.7472
# Epoch 21/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1911 - iou_score: 0.8271
# Epoch 21: val_loss did not improve from 0.26444
# 30/30 [==============================] - 6s 206ms/step - loss: 0.1911 - iou_score: 0.8271 - val_loss: 0.2710 - val_iou_score: 0.7663
# Epoch 22/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1626 - iou_score: 0.8533
# Epoch 22: val_loss did not improve from 0.26444
# 30/30 [==============================] - 7s 238ms/step - loss: 0.1626 - iou_score: 0.8533 - val_loss: 0.2654 - val_iou_score: 0.7810
# Epoch 23/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1748 - iou_score: 0.8423
# Epoch 23: val_loss improved from 0.26444 to 0.19114, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-023.hdf5
# 30/30 [==============================] - 12s 393ms/step - loss: 0.1748 - iou_score: 0.8423 - val_loss: 0.1911 - val_iou_score: 0.8279
# Epoch 24/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1591 - iou_score: 0.8563
# Epoch 24: val_loss improved from 0.19114 to 0.17816, saving model to /content/drive/MyDrive/checkpoints_vgg19/checkpoint-024.hdf5
# 30/30 [==============================] - 8s 282ms/step - loss: 0.1591 - iou_score: 0.8563 - val_loss: 0.1782 - val_iou_score: 0.8416
# Epoch 25/25
# 30/30 [==============================] - ETA: 0s - loss: 0.1586 - iou_score: 0.8564
# Epoch 25: val_loss did not improve from 0.17816
# 30/30 [==============================] - 7s 238ms/step - loss: 0.1586 - iou_score: 0.8564 - val_loss: 0.1846 - val_iou_score: 0.8368

# %%
from keras.models import load_model

model = load_model("/content/landcover_100_epochs_RESNET_backbone_batch16.hdf5", compile=False)

#batch_size=32 #Check IoU for a batch of images

#Test generator using validation data.

test_image_batch, test_mask_batch = val_img_gen.__next__()

#Convert categorical to integer for visualization and IoU calculation
test_mask_batch_argmax = np.argmax(test_mask_batch, axis=3) 
test_pred_batch = model.predict(test_image_batch)
test_pred_batch_argmax = np.argmax(test_pred_batch, axis=3)

n_classes = 4
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(test_pred_batch_argmax, test_mask_batch_argmax)
print("Mean IoU =", IOU_keras.result().numpy())

#######################################################
# Out:
# 1/1 [==============================] - 2s 2s/step
# Mean IoU = 0.89055103

# %%
#View a few images, masks and corresponding predictions. 
img_num = random.randint(0, test_image_batch.shape[0]-1)

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_image_batch[img_num])
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_mask_batch_argmax[img_num])
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(test_pred_batch_argmax[img_num])
plt.show()
